# %% [markdown]
# <a href="https://colab.research.google.com/github/EngMarceloPaulo/redesined-engeneering/blob/master/Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
NomeDaVariavel = 'Marcelo'
nomedavariavel = 'Paulo'
nome = NomeDaVariavel + ' ' + nomedavariavel
var = 45
var2 = 2
var3 = var + var2
print(nome)
print(var3)
print(NomeDaVariavel)
print(nomedavariavel)
# Out:
# Marcelo Paulo
# 47
# Marcelo
# Paulo
